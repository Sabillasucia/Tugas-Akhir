# %%
pip install python_speech_features
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python_speech_features in /usr/local/lib/python3.8/dist-packages (0.6)

# %%
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
from google.colab import drive
import os
import pandas as pd
import pywt
import csv
import os
from glob import glob
import shutil
from scipy.io import wavfile
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

# %%
drive.mount('/content/drive')
directory = "/content"
base_path = "/content/drive/MyDrive/Data Tugas Akhir"
N_path = f'{base_path}{os.sep}Normal/'
audio_files_N = glob(N_path  + '*.wav')
Preprocess_N = f'{base_path}{os.sep}Preprocess_N/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # MFCC

# %%
def feature_extraction(file_path):
    x,sample_rate = librosa.load(file_path, res_type='kaiser_best')
    mfcc = librosa.feature.mfcc(y=x, sr = sample_rate)
    return mfcc

# %%
features = {}
features_mfcc_test = []
directory2 = Preprocess_N
for audio in os.listdir(directory):
    audio_path = directory+audio
    features[audio_path] = feature_extraction(audio_path)
    features_mfcc_test.append(feature_extraction(audio_path))

# %%
features_mfcc_test

# %%
features

# %% [markdown]
# ## MFCC Mean

# %%
mfcc_means = []
for i in features_mfcc_test:
  mean = np.mean(i)
  mfcc_means.append(mean)

# %%
df_mean = pd.DataFrame(mfcc_means, columns=['Mean'])
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_mean.plot.line()

plt.title('Plot Mean')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %% [markdown]
# ## MFCC Std

# %%
mfcc_std = []
for i in features_mfcc_test:
  std = np.std(i)
  mfcc_std.append(std)

# %%
df_std = pd.DataFrame(mfcc_std, columns=['Std']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_std.plot.line()

plt.title('Plot std')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %% [markdown]
# ## MFCC Max

# %%
MFCC_max = []
for i in features_mfcc_test:
  max = np.max(i)
  MFCC_max.append(max)

# %%
df_max = pd.DataFrame(MFCC_max, columns=['Max']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_max.plot.line()

plt.title('Plot Max')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %% [markdown]
# ## MFCC Min

# %%
mfcc_Min = []
for i in features_mfcc_test:
  Min = np.min(i)
  mfcc_Min.append(Min)

# %%
df_min = pd.DataFrame(mfcc_Min, columns=['Min']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_min.plot.line()

plt.title('Plot Min')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
mfcc_Med = []
for i in features_mfcc_test:
  Med = np.median(i)
  mfcc_Med.append(Med)

# %%
df_med = pd.DataFrame(mfcc_Med, columns=['Med']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_med.plot.line()

plt.title('Plot Med')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
mfcc_Var = []
for i in features_mfcc_test:
  Var = np.var(i)
  mfcc_Var.append(Var)

# %%
df_var = pd.DataFrame(mfcc_Var, columns=['Var']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_var.plot.line()

plt.title('Plot Var')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
from scipy.stats import skew

# %%
mfcc_Skew = []
for i in features_mfcc_test:
  Skew = skew(i, axis=0, bias=True)
  mfcc_Skew.append(Skew)

# %%
skew_means = []
for i in mfcc_Skew:
  mean = np.mean(i)
  skew_means.append(mean)

# %%
df_skew = pd.DataFrame(skew_means, columns=['Skew']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_skew.plot.line()

plt.title('Plot Skew')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
mfcc_Q1 = []
for i in features_mfcc_test:
  Q1 = np.percentile(i, 25) 
  mfcc_Q1.append(Q1)

# %%
df_q1 = pd.DataFrame(mfcc_Q1, columns=['Q1']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_q1.plot.line()

plt.title('Plot Q1')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
mfcc_Q3 = []
for i in features_mfcc_test:
  Q3 = np.percentile(i, 75) 
  mfcc_Q3.append(Q3)

# %%
df_q3 = pd.DataFrame(mfcc_Q3, columns=['Q3']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_q3.plot.line()

plt.title('Plot Q3')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
mfcc_IQR = []
IQR = np.array(mfcc_Q3) - np.array(mfcc_Q1)
mfcc_IQR.append(IQR)

# %%
df_iqr = pd.DataFrame(mfcc_IQR)
df_iqr = df_iqr.transpose()
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_iqr.plot.line()

plt.title('Plot IQR')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
mfcc_range = []
Range = np.array(MFCC_max) - np.array(mfcc_Min)
mfcc_range.append(Range)

# %%
df_range = pd.DataFrame(mfcc_range)
df_range = df_range.transpose()
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_range.plot.line()

plt.title('Plot MinMax range')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
from scipy.stats import kurtosis

# %%
mfcc_Kurt = []
for i in features_mfcc_test:
  Kurt = kurtosis(i, axis=0, bias=True)
  mfcc_Kurt.append(Kurt)

# %%
kurt_means = []
for i in mfcc_Kurt:
  mean = np.mean(i)
  kurt_means.append(mean)

# %%
df_kurt = pd.DataFrame(kurt_means, columns=['Kurt']) 
plt.rcParams["figure.figsize"] = (20,3)

lines1 = df_kurt.plot.line()

plt.title('Plot Kurtosis')
plt.ylabel('Nilai')
plt.xlabel('Data Ke')
# Out:
# Text(0.5, 0, 'Data Ke')

# %%
df_mfcc = pd.DataFrame()
df_mfcc['Mean_mfcc'] = df_mean['Mean']
df_mfcc['Std_mfcc'] = df_std['Std']
df_mfcc['Max_mfcc'] = df_max['Max']
df_mfcc['Min_mfcc'] = df_min['Min']
df_mfcc['Med_mfcc'] = df_med['Med']
df_mfcc['Var_mfcc'] = df_var['Var']
df_mfcc['Skew_mfcc'] = df_skew['Skew']
df_mfcc['Q1_mfcc'] = df_q1['Q1']
df_mfcc['Q3_mfcc'] = df_q3['Q3']
df_mfcc['IQR_mfcc'] = df_iqr[0]
df_mfcc['MinMax_mfcc'] = df_range[0]
df_mfcc['Kurt_mfcc'] = df_kurt['Kurt']
df_mfcc
# Out:
#      Mean_mfcc    Std_mfcc    Max_mfcc     Min_mfcc  Med_mfcc      Var_mfcc  \
# 0   -46.217701  238.983566  159.284973 -1106.358765  0.000000  57113.148438
# 1   -46.105030  241.975830  240.152512 -1126.824341  1.178234  58552.300781
# 2   -44.472099  232.462341  158.644348 -1084.411011  0.814739  54038.738281
# 3   -42.932949  225.716125  187.793732 -1060.257202  0.171716  50947.769531
# 4   -43.993610  227.399200  193.295349 -1066.341553  1.180910  51710.394531
# ..         ...         ...         ...          ...       ...           ...
# 275 -45.097027  222.751221  214.149139 -1038.883667  0.629796  49618.105469
# 276 -45.623383  212.819809  161.043228  -993.348633  0.000000  45292.273438
# 277 -42.610847  228.144745  202.739441 -1054.615723  1.082222  52050.027344
# 278 -48.978481  239.742859  202.217712 -1119.360840  0.000000  57476.636719
# 279 -40.056068  205.819458  161.982117  -948.649414  0.000000  42361.648438
#
#      Skew_mfcc   Q1_mfcc    Q3_mfcc   IQR_mfcc  MinMax_mfcc  Kurt_mfcc
# 0    -4.102304  0.000000   9.435129   9.435129  1265.643799  14.914297
# 1    -4.084074  0.000000  11.527229  11.527229  1366.976807  14.830535
# 2    -4.088400 -0.983383  12.146240  13.129622  1243.055420  14.844934
# 3    -4.066360 -2.533281  10.940024  13.473306  1248.050903  14.737468
# 4    -4.068787 -1.881258  10.152344  12.033602  1259.636963  14.751711
# ..         ...       ...        ...        ...          ...        ...
# 275  -4.091184 -2.040021   7.060174   9.100196  1253.032837  14.861667
# 276  -4.085845 -1.702546   4.352267   6.054813  1154.391846  14.832828
# 277  -4.101206  0.000000  12.018722  12.018722  1257.355225  14.911761
# 278  -4.083815 -0.039892   5.476521   5.516413  1321.578613  14.826340
# 279  -4.112164  0.000000   8.954306   8.954306  1110.631592  14.965234
#
# [280 rows x 12 columns]

# %%
df_mfcc.to_csv("MFCC_Feature Extraction_N.csv")

# %% [markdown]
# # Shanon Entropy

# %%
from scipy.stats import entropy
def shannonenergycount(file_path):
    x,sample_rate = librosa.load(file_path, res_type='kaiser_best')
    x_series = pd.Series(x)
    counts = x_series.value_counts()
    entropy_shanon = entropy(counts)
    return entropy_shanon

# %%
shanonenergy = []
shanonpath = Preprocess_N
for audio in os.listdir(shanonpath):
    audio_path = shanonpath+audio
    results = shannonenergycount(audio_path)
    shanonenergy.append(results)

# %%
shanonenergy
# Out:
# [13.400527150256721,
#  13.400654195922456,
#  13.400412678689499,
#  13.40030919921582,
#  13.400106708959001,
#  13.400200737373485,
#  13.40030160748596,
#  13.400756370715534,
#  13.40055937650549,
#  13.400078674076404,
#  13.400162501399828,
#  13.400200223695368,
#  13.400191840963027,
#  13.400722839786166,
#  13.39947824038707,
#  13.400238736993394,
#  13.400481045228839,
#  13.400517462843778,
#  13.400121378740602,
#  13.400669656706542,
#  13.400408487323327,
#  13.400995001262924,
#  13.400327269361105,
#  13.399731304362312,
#  13.40009385753612,
#  13.399967602872866,
#  13.40043703588404,
#  13.400824737254874,
#  13.399797061540449,
#  13.399523554412468,
#  13.400477644865152,
#  13.400423157104926,
#  13.400177171181427,
#  13.399444195779585,
#  13.400622760676175,
#  13.399846053253903,
#  13.400403504954673,
#  13.40011430068886,
#  13.399147399783915,
#  13.400525845576121,
#  13.400557280822404,
#  13.39997151691467,
#  13.400471357815894,
#  13.400126874787373,
#  13.400558585503004,
#  13.400331460727276,
#  13.400080769759489,
#  13.399400463759157,
#  13.399105486122204,
#  13.40018844059934,
#  13.400530550620408,
#  13.40038045244073,
#  13.400344034825789,
#  13.400562776869176,
#  13.400032569048522,
#  13.40048812328058,
#  13.399871992453415,
#  13.399975194602726,
#  13.400592116432374,
#  13.399688877022484,
#  13.400578751331377,
#  13.399665033506057,
#  13.39961813747569,
#  13.400008725532095,
#  13.399966534546014,
#  13.400532132625377,
#  13.399954237771869,
#  13.400611768582628,
#  13.400782823593163,
#  13.399203705902858,
#  13.400129761472943,
#  13.400644508509515,
#  13.400434149198471,
#  13.4001653880854,
#  13.400232963622255,
#  13.40004304746395,
#  13.399882470868844,
#  13.40011718737443,
#  13.400031778046037,
#  13.400487332278095,
#  13.40043703588404,
#  13.400602594847802,
#  13.400517462843778,
#  13.399302480332251,
#  13.3992254537362,
#  13.399952142088784,
#  13.400448305301955,
#  13.400066099977892,
#  13.400036760414691,
#  13.400403504954673,
#  13.4004286531517,
#  13.400785710278734,
#  13.399694373069256,
#  13.400189981633687,
#  13.40029322475362,
#  13.39914530410083,
#  13.400844903083247,
#  13.400353208560619,
#  13.400189745279942,
#  13.400089152491834,
#  13.40042106142184,
#  13.399445500460187,
#  13.39967918960954,
#  13.400584524702516,
#  13.400087056808745,
#  13.399869105767845,
#  13.400235850307824,
#  13.40075269302748,
#  13.400624342681144,
#  13.400703978638395,
#  13.400514576158207,
#  13.400291129070535,
#  13.400213588796367,
#  13.401099271739088,
#  13.40035111287753,
#  13.40085905918673,
#  13.40007499638835,
#  13.400406905318357,
#  13.39999354207238,
#  13.399066972824178,
#  13.3986682793598,
#  13.399856531669332,
#  13.39961683279509,
#  13.399785278444421,
#  13.399849453617591,
#  13.40022616289488,
#  13.400709474685167,
#  13.400190536282427]

# %%
shanonlist = shanonenergy
df_shanon = pd.DataFrame([shanonlist])
df_shanon
# Out:
#          0          1          2          3          4          5    \
# 0  13.400527  13.400654  13.400413  13.400309  13.400107  13.400201
#
#          6          7          8          9    ...        270        271  \
# 0  13.400302  13.400756  13.400559  13.400079  ...  13.399994  13.399067
#
#          272        273        274        275        276        277  \
# 0  13.398668  13.399857  13.399617  13.399785  13.399849  13.400226
#
#          278        279
# 0  13.400709  13.400191
#
# [1 rows x 280 columns]

# %%
df_shanon_transposed = df_shanon.transpose()
df_shanon_transposed
# Out:
#              0
# 0    13.400527
# 1    13.400654
# 2    13.400413
# 3    13.400309
# 4    13.400107
# ..         ...
# 275  13.399785
# 276  13.399849
# 277  13.400226
# 278  13.400709
# 279  13.400191
#
# [280 rows x 1 columns]

# %%
df_shanon_transposed.rename(columns={0: "Entropy"}, inplace=True)

# %%
df_shanon_transposed.to_csv("Shannon_Feature Extraction_N.csv")

# %%
plt.figure(figsize=(18, 8))
plt.title("Shannon Entropy of Normal Signal")
plt.plot(df_shanon_transposed)
plt.ylabel('Entropy')
plt.xlabel('Iterasi file')
plt.show()
